# %% [markdown]
# # Predicting the images after training the model 3

# %% [markdown]
# ### Imports

# %%
import sys
import os
import tensorflow as tf

current_dir = os.getcwd()

# Define the project root relative to the current working directory
project_root = os.path.abspath(os.path.join(current_dir, "../"))  # Adjust this based on your folder structure

# Add project_root to sys.path
sys.path.append(project_root)

from src.inference.predict import PredictionContext, ImageClassifier

# %%
# Load the model
model = tf.keras.models.load_model("./saved_model/final_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
image_path = "../data/raw/United_Airlines_Boeing_777-200_Meulemans.jpg"

# %%
# Class labels for CIFAR-10 dataset
class_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Initialize prediction strategy
predictor = PredictionContext(ImageClassifier())

# %%
# Run prediction

predicted_class, prediction_values = predictor.execute_prediction(model, image_path, class_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Predicted Class: airplane
